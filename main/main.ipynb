# %%
import langchain

# %%
import os
# os module provides a way of using operating system dependent functionality like reading or writing to the file system, handling environment variables, and interacting with the operating system in general. In this code, it is likely being used to access environment variables that may contain sensitive information such as API keys or database credentials.
from dotenv import load_dotenv
# load_dotenv() why we initializing the load_dotenv() function?
# The load_dotenv() function is used to load environment variables from a .env file into the environment. This allows you to keep sensitive information, such as API keys or database credentials, separate from your code and easily manage them in a single file. By calling load_dotenv(), you ensure that the environment variables defined in the .env file are available for use in your application.
load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"] = os.environ.get('GROQ_API_KEY')
# This line of code is setting an environment variable named "GROQ_API_KEY" to the value retrieved from the existing environment variable

# %%
# calling the Groq API using the langchain library
from langchain.chat_models import init_chat_model
from langchain_core.messages import HumanMessage, SystemMessage
# The above code is importing the necessary modules and classes from the langchain library to initialize a chat model and create messages for the chatbot. The init_chat_model function is used to initialize the chat model, while HumanMessage and SystemMessage are classes that represent different types of messages in the chatbot conversation. HumanMessage typically represents messages from the user, while SystemMessage represents messages from the system or chatbot itself.

# %%
model = init_chat_model("groq:meta-llama/llama-prompt-guard-2-86m")
model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File d:\chatbot_1\.venv\Lib\site-packages\langchain\chat_models\base.py:118, in _import_module(module, class_name)
#     117 try:
# --> 118     return importlib.import_module(module)
#     119 except ImportError as e:
#     120     # Extract package name from module path (e.g., "langchain_azure_ai.chat_models"
#     121     # becomes "langchain-azure-ai")
#
# File C:\Program Files\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'langchain_groq'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 model = init_chat_model("groq:meta-llama/llama-prompt-guard-2-86m")
#       2 model
#
# File d:\chatbot_1\.venv\Lib\site-packages\langchain\chat_models\base.py:477, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     469     warnings.warn(
#     470         f"{config_prefix=} has been set but no fields are configurable. Set "
#     471         f"`configurable_fields=(...)` to specify the model params that are "
#     472         f"configurable.",
#     473         stacklevel=2,
#     474     )
#     476 if not configurable_fields:
# --> 477     return _init_chat_model_helper(
#     478         cast("str", model),
#     479         model_provider=model_provider,
#     480         **kwargs,
#     481     )
#     482 if model:
#     483     kwargs["model"] = model
#
# File d:\chatbot_1\.venv\Lib\site-packages\langchain\chat_models\base.py:500, in _init_chat_model_helper(model, model_provider, **kwargs)
#     493 def _init_chat_model_helper(
#     494     model: str,
#     495     *,
#     496     model_provider: str | None = None,
#     497     **kwargs: Any,
#     498 ) -> BaseChatModel:
#     499     model, model_provider = _parse_model(model, model_provider)
# --> 500     creator_func = _get_chat_model_creator(model_provider)
#     501     return creator_func(model=model, **kwargs)
#
# File d:\chatbot_1\.venv\Lib\site-packages\langchain\chat_models\base.py:158, in _get_chat_model_creator(provider)
#     156 pkg, class_name, creator_func = _BUILTIN_PROVIDERS[provider]
#     157 try:
# --> 158     module = _import_module(pkg, class_name)
#     159 except ImportError as e:
#     160     if provider != "ollama":
#
# File d:\chatbot_1\.venv\Lib\site-packages\langchain\chat_models\base.py:127, in _import_module(module, class_name)
#     122 pkg = module.split(".", maxsplit=1)[0].replace("_", "-")
#     123 msg = (
#     124     f"Initializing {class_name} requires the {pkg} package. Please install it "
#     125     f"with `pip install {pkg}`"
#     126 )
# --> 127 raise ImportError(msg) from e
#
# ImportError: Initializing ChatGroq requires the langchain-groq package. Please install it with `pip install langchain-groq`
